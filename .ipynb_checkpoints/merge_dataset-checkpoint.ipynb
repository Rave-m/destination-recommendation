# %%
# !pip install pandas
# !pip install numpy
# Out:
# Collecting pandas
#   Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Downloading numpy-2.2.4-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\ml\rekomendasi-destinasi-wisata\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in d:\ml\rekomendasi-destinasi-wisata\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl (11.5 MB)
# Downloading numpy-2.2.4-cp312-cp312-win_amd64.whl (12.6 MB)
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ----- ---------------------------------- 1.8/12.6 MB 11.2 MB/s eta 0:00:01
#    -------------- ------------------------- 4.5/12.6 MB 12.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 7.3/12.6 MB 12.6 MB/s eta 0:00:01
#    ------------------------------- -------- 10.0/12.6 MB 12.7 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.6 MB 12.9 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 12.6 MB/s eta 0:00:00
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, numpy, pandas
# Successfully installed numpy-2.2.4 pandas-2.2.3 pytz-2025.2 tzdata-2025.2
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy in d:\ml\rekomendasi-destinasi-wisata\.venv\lib\site-packages (2.2.4)
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np

# %%
reviews = 'results/reviews.csv'
details = 'results/details.csv'

reviews_df = pd.read_csv(reviews)
details_df = pd.read_csv(details)

# %%
reviews_df.head()
# Out:
#               nama_destinasi           username  \
# 0  Ramayana Ballet Prambanan                 MK
# 1  Ramayana Ballet Prambanan   Miranda Tjahjadi
# 2  Ramayana Ballet Prambanan          Riqi Riqi
# 3  Ramayana Ballet Prambanan     Muhammad Iqbal
# 4  Ramayana Ballet Prambanan  Intan Ama Yuniari
#
#                                             komentar   rating     tanggal
# 0  Selalu suka dengan pertunjukan nya, sedih krn ...  5,0\n/5  8 Apr 2025
# 1  Sangatt sangatt baguss dan sangattt recomended...  5,0\n/5  7 Apr 2025
# 2     Pengalaman pertunjukan kebudayaan jawa terbaik  5,0\n/5  5 Apr 2025
# 3  Ngk nyesalll nnton ini walaupun di indoor tapi...  5,0\n/5  4 Mar 2025
# 4         bagus bgttttttttttttttttttttttrtttrttrrttt  5,0\n/5  1 Mar 2025

# %%
details_df.head()
# Out:
#                      nama_destinasi           rating_destinasi        harga  \
# 0         Ramayana Ballet Prambanan    4,8/5\n(\n290 Review\n)  IDR 150.000
# 1  Legenda Roro Jonggrang Prambanan     4,7/5\n(\n78 Review\n)  IDR 100.000
# 2       Tiket Masuk Candi Prambanan  4,5/5\n(\n3.5rb Review\n)   IDR 50.000
# 3                   Candi Ratu Boko    4,8/5\n(\n182 Review\n)   IDR 21.000
# 4                       HeHa Forest        4/5\n(\n1 Review\n)   IDR 25.000
#
#               lokasi
# 0    Kalasan, Sleman
# 1  Prambanan, Sleman
# 2  Prambanan, Sleman
# 3  Prambanan, Sleman
# 4      Pakem, Sleman

# %%
reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4035 entries, 0 to 4034
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   nama_destinasi  4035 non-null   object
#  1   username        4021 non-null   object
#  2   komentar        4035 non-null   object
#  3   rating          4035 non-null   object
#  4   tanggal         4035 non-null   object
# dtypes: object(5)
# memory usage: 157.7+ KB

# %%
details_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   nama_destinasi    17 non-null     object
#  1   rating_destinasi  17 non-null     object
#  2   harga             17 non-null     object
#  3   lokasi            17 non-null     object
# dtypes: object(4)
# memory usage: 676.0+ bytes

# %%
destinasi_review = reviews_df['nama_destinasi'].unique().tolist()
destinasi_detail = details_df['nama_destinasi'].unique().tolist()

print(f"destinasi reviews {len(destinasi_review)} : ")
print(f"{destinasi_review}")

print("\n")
print(f"destinasi details : {destinasi_detail}")
# Out:
# destinasi reviews : ['Ramayana Ballet Prambanan', 'Legenda Roro Jonggrang Prambanan', 'Tiket Masuk Candi Prambanan', 'Candi Ratu Boko', 'HeHa Forest', 'Official Tickets | Ramayana Ballet Purawisata – 48 Years', 'La Li Sa European Park', 'Waterboom Jogja', 'De MANGOL VIEW', 'The Legend of Roro Jonggrang Ticket in Yogyakarta', 'Jomblang Cave Experience in Yogyakarta', 'Merapi Jeep Ticket in Yogyakarta', 'Merapi Park Jogja']
#
#
# destinasi details : ['Ramayana Ballet Prambanan', 'Legenda Roro Jonggrang Prambanan', 'Tiket Masuk Candi Prambanan', 'Candi Ratu Boko', 'HeHa Forest', 'Official Tickets | Ramayana Ballet Purawisata – 48 Years', 'La Li Sa European Park', 'Waterboom Jogja', 'De MANGOL VIEW', 'Kaliurang Park Botanical Garden', 'The Legend of Roro Jonggrang Ticket in Yogyakarta', 'Jomblang Cave Experience in Yogyakarta', 'Merapi Jeep Ticket in Yogyakarta', 'Merapi Park Jogja', 'Java Puppets Museum Admission Ticket', 'Private Borobudur Sunrise and Prambanan Temple Tour', 'Borobudur Temple Private Tour with German Speaking Guide']
